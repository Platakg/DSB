# %%
import pandas as pd
import matplotlib

import matplotlib.pyplot as plt
# %matplotlib inline


path = '/Users/kathrynruhl/DSB4VE/class.csv'
data = pd.read_csv(path)

print(list(data))

print((data['Frequency'], data['Classes'].unique))


#data.plot.hist(by='Frequency')
data.plot(x="Classes", y="Frequency", kind="bar", title="Image Class by Frequency", figsize=(10,7))
# Out:
# ['Classes', 'Frequency']
# (0     16
# 1     71
# 2     41
# 3      8
# 4    599
# Name: Frequency, dtype: int64, <bound method Series.unique of 0      Black Fore, White Back
# 1    Purple Fore, Purple Back
# 2     Purple Fore, White Back
# 3    Purple Fore, Yellow Back
# 4      White Fore, Black Back
# Name: Classes, dtype: object>)
